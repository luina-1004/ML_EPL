# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:/Users/NTX550/Desktop/권지원/ML/EPL/ML_EPL/EPL/epl__ (2).xlsx"
data = pd.read_excel(path)
data.head()
# Out:
#            Date                 Home               Away  H_Possession  \
# 0  20.06.18 (목)        Aston Villa     Sheffield United          45.1
# 1  20.06.18 (목)    Manchester City              Arsenal          67.1
# 2  20.06.20 (토)       Norwich City          Southampton          55.0
# 3  20.06.20 (토)  Tottenham Hotspur    Manchester United          38.8
# 4  20.06.20 (토)            Watford       Leicester City          31.7
#
#    A_Possession  H_Shots on target  A_Shots on target  H_Shots  A_Shots  \
# 0          54.9                  6                  1       14        5
# 1          32.9                 12                  0       20        3
# 2          45.0                  1                  9        9       22
# 3          61.2                  3                  6       10       12
# 4          68.3                  4                  2        8       15
#
#    H_Touches  ...  H_Corners  A_Corners  H_Offsides  A_Offsides  \
# ...

# %%
data
# Out:
#               Date                      Home               Away  H_Possession  \
# 0     20.06.18 (목)             Aston Villa     Sheffield United          45.1
# 1     20.06.18 (목)         Manchester City              Arsenal          67.1
# 2     20.06.20 (토)            Norwich City          Southampton          55.0
# 3     20.06.20 (토)       Tottenham Hotspur    Manchester United          38.8
# 4     20.06.20 (토)                 Watford       Leicester City          31.7
# ...            ...                       ...                ...           ...
# 1156  23.05.08 (월)        Newcastle United              Arsenal          54.3
# 1157  23.05.08 (월)         West Ham United    Manchester United          34.7
# 1158  23.05.08 (월)                  Fulham       Leicester City          57.1
# 1159  23.05.09 (화)  Brighton & Hove Albion              Everton          77.7
# 1160  23.05.09 (화)       Nottingham Forest          Southampton          35.9
#
# ...

# %%
path = "C:/Users/NTX550/Desktop/권지원/ML/EPL/ML_EPL/EPL/BETMAN_ALL (1).xlsx"
data2 = pd.read_excel(path)
data2.head()
# Out:
#               MCH_DTM HOME_TEAM AWAY_TEAM  U_ODDS  O_ODDS  UO_STANDARD  \
# 0  20.06.18 (목) 02:00       애스턴      셰필드U    1.88    1.62          2.5
# 1  20.06.18 (목) 04:15      맨체스C       아스널    1.82    1.67          3.5
# 2  20.06.20 (토) 02:00       노리치      사우샘프    1.73    1.75          2.5
# 3  20.06.20 (토) 04:15       토트넘      맨체스U    1.80    1.68          2.5
# 4  20.06.20 (토) 20:30       왓포드       레스터    1.77    1.71          2.5
#
#    HOME_SCORE  AWAY_SCORE  MCH_SCORE  GAME_RESULT UO_RESULT   GM_TS  GM_SEQ  \
# 0           0           0          0            0         U  200035     102
# 1           3           0          3            0         U  200035     123
# 2           0           3          3            2         O  200036      36
# 3           1           1          2            0         U  200036      45
# 4           1           1          2            0         U  200036      99
#
#   PR_LL_WIN_LEAG_NM
# 0               EPL
# 1               EPL
# ...

# %%
team_mapping = {
'애스턴' : 'Aston Villa'
,'맨체스C' : 'Manchester City'
,'노리치' : 'Norwich City'
,'토트넘' : 'Tottenham Hotspur'
,'왓포드' : 'Watford '
,'브라이턴' : 'Brighton & Hove Albion'
,'웨스트햄' : 'West Ham United'
,'본머스' : 'Bournemouth'
,'뉴캐슬' : 'Newcastle United'
,'에버턴' : 'Everton'
,'레스터' : 'Leicester City'
,'울버햄튼' : 'Wolverhampton Wanderers'
,'맨체스U' : 'Manchester United'
,'리버풀' : 'Liverpool'
,'번리' : 'Burnley'
,'사우샘프' :  'Southampton'
,'첼시' : 'Chelsea'
,'크리스탈' : 'Crystal Palace'
,'아스널' : 'Arsenal'
,'셰필드U' : 'Sheffield United'
,'풀럼' : 'Fulham'
,'웨스브로' : 'West Bromwich Albion'
,'리즈' : 'Leeds United'
,'울버햄프' : 'Wolverhampton Wanderers'
,'브렌트퍼' : 'Brentford'
,'크리스털' : 'Crystal Palace'
,'노팅엄포' : 'Nottingham Forest'
}

data2['HOME_TEAM'] = data2['HOME_TEAM'].map(team_mapping)
data2['AWAY_TEAM'] = data2['AWAY_TEAM'].map(team_mapping)

# %%
data2
# Out:
#                  MCH_DTM               HOME_TEAM          AWAY_TEAM  U_ODDS  \
# 0     20.06.18 (목) 02:00             Aston Villa   Sheffield United    1.88
# 1     20.06.18 (목) 04:15         Manchester City            Arsenal    1.82
# 2     20.06.20 (토) 02:00            Norwich City        Southampton    1.73
# 3     20.06.20 (토) 04:15       Tottenham Hotspur  Manchester United    1.80
# 4     20.06.20 (토) 20:30                Watford      Leicester City    1.77
# ...                  ...                     ...                ...     ...
# 1156  23.05.08 (월) 00:30                     NaN                NaN    1.49
# 1157  23.05.08 (월) 03:00         West Ham United                NaN    1.55
# 1158  23.05.08 (월) 23:00                     NaN                NaN    1.61
# 1159  23.05.09 (화) 01:30  Brighton & Hove Albion                NaN    2.13
# 1160  23.05.09 (화) 04:00       Nottingham Forest        Southampton    1.82
#
# ...

# %%
data2[data2['AWAY_TEAM'].isnull()]
# Out:
#                  MCH_DTM                HOME_TEAM AWAY_TEAM  U_ODDS  O_ODDS  \
# 110   20.09.29 (화) 01:45                      NaN       NaN    1.90    1.57
# 111   20.09.29 (화) 04:00                      NaN       NaN    2.14    1.44
# 114   20.10.04 (일) 01:30                      NaN       NaN    1.86    1.60
# 115   20.10.04 (일) 04:00                      NaN       NaN    2.07    1.47
# 118   20.10.04 (일) 22:00  Wolverhampton Wanderers       NaN    1.81    1.64
# ...                  ...                      ...       ...     ...     ...
# 1154  23.05.06 (토) 23:00                      NaN       NaN    1.67    1.86
# 1156  23.05.08 (월) 00:30                      NaN       NaN    1.49    2.15
# 1157  23.05.08 (월) 03:00          West Ham United       NaN    1.55    2.04
# 1158  23.05.08 (월) 23:00                      NaN       NaN    1.61    1.94
# 1159  23.05.09 (화) 01:30   Brighton & Hove Albion       NaN    2.13    1.50
#
# ...
