# %%
import pandas as pd
import numpy as np

# %%
path = 'C:/Users/NTX550/Desktop/권지원/ML/EPL/ML_EPL/EPL/시각화.xlsx'
df = pd.read_excel(path)
df.head()
# Out:
#            Date                    Home               Away  H_Possession  \
# 0  23.05.09 (화)       Nottingham Forest        Southampton          35.9
# 1  23.05.09 (화)  Brighton & Hove Albion            Everton          77.7
# 2  23.05.08 (월)         West Ham United  Manchester United          34.7
# 3  23.05.08 (월)        Newcastle United            Arsenal          54.3
# 4  23.05.08 (월)                  Fulham     Leicester City          57.1
#
#    A_Possession  H_Shots on target  A_Shots on target  H_Shots  A_Shots  \
# 0          64.1                  4                  5        9       19
# 1          22.3                  5                  5       23       10
# 2          65.3                  4                  4       15       19
# 3          45.7                  5                  6       12       10
# 4          42.9                  7                  9       17       18
#
#    H_Touches  ...  H_ratio  A_ratio  H_score  A_score  U_ODDS  O_ODDS  \
# ...

# %%
from sklearn.preprocessing import Imputer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.preprocessing import Imputer
#
# ImportError: cannot import name 'Imputer' from 'sklearn.preprocessing' (c:\Users\NTX550\anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py)
