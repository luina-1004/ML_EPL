# %%
import pandas as pd
import numpy as np

# %%
from pandas.api.types import is_numeric_dtype
from sklearn.cluster import KMeans

# %%
path = "C:/Users/NTX550/Desktop/권지원/ML/EPL/ML_EPL/EPL/underrover__ML.xlsx"
unov = pd.read_excel(path, index_col=0)
unov.columns
# Out:
# Index(['Date', 'Home', 'Away', 'H_Possession', 'A_Possession',
#        'H_Shots on target', 'A_Shots on target', 'H_Shots', 'A_Shots',
#        'H_Touches', 'A_Touches', 'H_Passes', 'A_Passes', 'H_Tackles',
#        'A_Tackles', 'H_Clearances', 'A_Clearances', 'H_Corners', 'A_Corners',
#        'H_Offsides', 'A_Offsides', 'H_Yellow cards', 'A_Yellow cards',
#        'H_Red cards', 'A_Red cards', 'H_Fouls', 'A_Fouls', 'U_ODDS', 'O_ODDS',
#        'UO_STANDARD', 'HOME_SCORE', 'AWAY_SCORE', 'MCH_SCORE', 'GAME_RESULT'],
#       dtype='object')

# %%
unov.head()
# Out:
#            Date                    Home               Away  H_Possession  \
# 0  23.05.09 (화)  Brighton & Hove Albion            Everton          77.7
# 1  23.05.09 (화)       Nottingham Forest        Southampton          35.9
# 2  23.05.08 (월)                  Fulham     Leicester City          57.1
# 3  23.05.08 (월)        Newcastle United            Arsenal          54.3
# 4  23.05.08 (월)         West Ham United  Manchester United          34.7
#
#    A_Possession  H_Shots on target  A_Shots on target  H_Shots  A_Shots  \
# 0          22.3                  5                  5       23       10
# 1          64.1                  4                  5        9       19
# 2          42.9                  7                  9       17       18
# 3          45.7                  5                  6       12       10
# 4          65.3                  4                  4       15       19
#
#    H_Touches  ...  A_Red cards  H_Fouls  A_Fouls  U_ODDS  O_ODDS  UO_STANDARD  \
# ...

# %%
val = 'Arsenal'
a = unov.sort_values(by = 'Home')
a
# Out:
#               Date                     Home                     Away  \
# 604   21.11.07 (일)                  Arsenal                  Watford
# 779   21.04.18 (일)                  Arsenal                   Fulham
# 981   20.11.30 (월)                  Arsenal  Wolverhampton Wanderers
# 771   21.04.24 (토)                  Arsenal                  Everton
# 1349  19.10.28 (월)                  Arsenal           Crystal Palace
# ...            ...                      ...                      ...
# 887   21.02.03 (수)  Wolverhampton Wanderers                  Arsenal
# 435   22.03.19 (토)  Wolverhampton Wanderers             Leeds United
# 876   21.02.07 (일)  Wolverhampton Wanderers           Leicester City
# 915   21.01.16 (토)  Wolverhampton Wanderers     West Bromwich Albion
# 1113  20.07.12 (일)  Wolverhampton Wanderers                  Everton
#
#       H_Possession  A_Possession  H_Shots on target  A_Shots on target  \
# ...

# %%
a = unov.groupby(['Home']).rolling(3).mean()
# a = unov.groupby(by = 'Home').rolling(window = 5, min_periods=1).mean()
# 1) lambda 2) excel로 따로
a
# Out:
# C:\Users\NTX550\AppData\Local\Temp\ipykernel_16868\2397864985.py:1: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Away', 'Date'], dtype='object')
#   a = unov.groupby(['Home']).rolling(3).mean()
#                               H_Possession  A_Possession  H_Shots on target  \
# Home
# Arsenal                 13             NaN           NaN                NaN
#                         35             NaN           NaN                NaN
#                         71       65.366667     34.633333           7.333333
#                         77       67.833333     32.166667           5.666667
#                         98       69.800000     30.200000           6.666667
# ...                                    ...           ...                ...
# Wolverhampton Wanderers 1545     58.100000     41.900000           4.333333
# ...

# %%
# a = unov.groupby(['Home']).rolling(window = 3).mean().shift(-2)

a = unov.groupby(['Home']).rolling(window = 3).mean().shift(-2).reset_index(drop=False, inplace=False)
# a
b = a.set_index(keys='level_1', drop=True, inplace=False)
b
# Out:
# C:\Users\NTX550\AppData\Local\Temp\ipykernel_16868\893901505.py:3: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Away', 'Date'], dtype='object')
#   a = unov.groupby(['Home']).rolling(window = 3).mean().shift(-2).reset_index(drop=False, inplace=False)
#                             Home  H_Possession  A_Possession  \
# level_1
# 13                       Arsenal     65.366667     34.633333
# 35                       Arsenal     67.833333     32.166667
# 71                       Arsenal     69.800000     30.200000
# 77                       Arsenal     71.800000     28.200000
# 98                       Arsenal     72.233333     27.766667
# ...                          ...           ...           ...
# 1545     Wolverhampton Wanderers     56.833333     43.166667
# ...

# %%
c = b
c['H_Possession']= c['H_Possession'].fillna(0)
c
# Out:
#                             Home  H_Possession  A_Possession  \
# level_1
# 13                       Arsenal     65.366667     34.633333
# 35                       Arsenal     67.833333     32.166667
# 71                       Arsenal     69.800000     30.200000
# 77                       Arsenal     71.800000     28.200000
# 98                       Arsenal     72.233333     27.766667
# ...                          ...           ...           ...
# 1545     Wolverhampton Wanderers     56.833333     43.166667
# 1568     Wolverhampton Wanderers     53.266667     46.733333
# 1596     Wolverhampton Wanderers     50.733333     49.266667
# 1608     Wolverhampton Wanderers      0.000000           NaN
# 1624     Wolverhampton Wanderers      0.000000           NaN
#
#          H_Shots on target  A_Shots on target    H_Shots    A_Shots  \
# level_1
# 13                7.333333           5.000000  18.000000   7.333333
# 35                5.666667           5.333333  17.666667   8.000000
# ...

# %%
b[b['Home'] =='Arsenal'] # 인덱스를 칼럼 -> 전체 데이터 인덱스랑 일치
# Out:
#             Home  H_Possession  A_Possession  H_Shots on target  \
# level_1
# 13       Arsenal     65.366667     34.633333           7.333333
# 35       Arsenal     67.833333     32.166667           5.666667
# 71       Arsenal     69.800000     30.200000           6.666667
# 77       Arsenal     71.800000     28.200000           6.333333
# 98       Arsenal     72.233333     27.766667           5.000000
# ...          ...           ...           ...                ...
# 1550     Arsenal     65.933333     34.066667           5.000000
# 1563     Arsenal     56.233333     43.766667           4.333333
# 1593     Arsenal     55.400000     44.600000           6.000000
# 1606     Arsenal           NaN           NaN                NaN
# 1626     Arsenal           NaN           NaN                NaN
#
#          A_Shots on target    H_Shots    A_Shots   H_Touches   A_Touches  \
# level_1
# 13                5.000000  18.000000   7.333333  794.333333  511.000000
# ...

# %%
unov.loc[:,"H_Poss_M"] = c.loc[:,['H_Possession']]

# %%
unov
# Out:
#               Date                     Home               Away  H_Possession  \
# 0     23.05.09 (화)   Brighton & Hove Albion            Everton          77.7
# 1     23.05.09 (화)        Nottingham Forest        Southampton          35.9
# 2     23.05.08 (월)                   Fulham     Leicester City          57.1
# 3     23.05.08 (월)         Newcastle United            Arsenal          54.3
# 4     23.05.08 (월)          West Ham United  Manchester United          34.7
# ...            ...                      ...                ...           ...
# 1624  19.01.03 (목)  Wolverhampton Wanderers     Crystal Palace          51.9
# 1625  19.01.03 (목)         Newcastle United  Manchester United          34.9
# 1626  19.01.02 (수)                  Arsenal             Fulham          59.6
# 1627  19.01.02 (수)             Cardiff City  Tottenham Hotspur          26.9
# 1628  19.01.01 (화)                  Everton     Leicester City          59.6
#
# ...

# %%
col = (unov['Home']=='Arsenal')
filtered = unov.loc[col,:]
filtered
# a=filtered.groupby(by=['Home']).rolling(window = 3).mean()
# a = unov.groupby(by = 'Home').rolling(window = 5, min_periods=1).mean()
# 1) apply lambda 2) excel로 따로 try except
# a

# %%
def recent_5_mean(data, group_var, variable, lag_num):
    final_data = pd.DataFrame()
    for var in variable:
       lag_data = data.groupby(group_var)[var].shift().rolling(lag_num).mean()
       final_data[var] = lag_data
    return final_data

sum_var = unov.columns[3:27].tolist()
group_var = ['Home']
group_var2 = ['Home','Date']
sum_var
# Out:
# ['H_Possession',
#  'A_Possession',
#  'H_Shots on target',
#  'A_Shots on target',
#  'H_Shots',
#  'A_Shots',
#  'H_Touches',
#  'A_Touches',
#  'H_Passes',
#  'A_Passes',
#  'H_Tackles',
#  'A_Tackles',
#  'H_Clearances',
#  'A_Clearances',
#  'H_Corners',
#  'A_Corners',
#  'H_Offsides',
#  'A_Offsides',
#  'H_Yellow cards',
#  'A_Yellow cards',
#  'H_Red cards',
#  'A_Red cards',
#  'H_Fouls',
#  'A_Fouls']

# %%
summary = recent_5_mean(unov,group_var, sum_var, 5)

# %%
summary
# Out:
#       H_Possession  A_Possession  H_Shots on target  A_Shots on target  \
# 0              NaN           NaN                NaN                NaN
# 1              NaN           NaN                NaN                NaN
# 2              NaN           NaN                NaN                NaN
# 3              NaN           NaN                NaN                NaN
# 4              NaN           NaN                NaN                NaN
# ...            ...           ...                ...                ...
# 1624         44.76         55.24                4.4                3.0
# 1625         47.76         52.24                4.8                3.0
# 1626         41.72         58.28                4.6                2.8
# 1627         43.02         56.98                4.2                2.4
# 1628         44.92         55.08                4.2                3.4
#
#       H_Shots  A_Shots  H_Touches  A_Touches  H_Passes  A_Passes  ...  \
# ...
