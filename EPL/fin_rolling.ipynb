# %%
import pandas as pd
import numpy as np

# %%
from pandas.api.types import is_numeric_dtype
from sklearn.cluster import KMeans

# %%
path = "C:/Users/NTX550/Desktop/권지원/ML/EPL/ML_EPL/EPL/underrover__ML.xlsx"
unov = pd.read_excel(path, index_col=0)
unov.columns
# Out:
# Index(['Date', 'Home', 'Away', 'H_Possession', 'A_Possession',
#        'H_Shots on target', 'A_Shots on target', 'H_Shots', 'A_Shots',
#        'H_Touches', 'A_Touches', 'H_Passes', 'A_Passes', 'H_Tackles',
#        'A_Tackles', 'H_Clearances', 'A_Clearances', 'H_Corners', 'A_Corners',
#        'H_Offsides', 'A_Offsides', 'H_Yellow cards', 'A_Yellow cards',
#        'H_Red cards', 'A_Red cards', 'H_Fouls', 'A_Fouls', 'U_ODDS', 'O_ODDS',
#        'UO_STANDARD', 'HOME_SCORE', 'AWAY_SCORE', 'MCH_SCORE', 'GAME_RESULT'],
#       dtype='object')

# %%
unov = unov.sort_values(by='Date',ascending=True).reset_index(drop=True)

# %%
unov.to_excel('unov.xlsx')

# %%
unov.iloc[[13,35,71],:]
# Out:
#             Date               Home                     Away  H_Possession  \
# 13  19.01.13 (일)       Cardiff City        Huddersfield Town          38.9
# 35  19.01.30 (수)   Newcastle United          Manchester City          23.8
# 71  19.02.27 (수)  Huddersfield Town  Wolverhampton Wanderers          49.9
#
#     A_Possession  H_Shots on target  A_Shots on target  H_Shots  A_Shots  \
# 13          61.1                  0                  2        3       14
# 35          76.2                  2                  4        7       12
# 71          50.1                  3                  0       15        7
#
#     H_Touches  ...  A_Red cards  H_Fouls  A_Fouls  U_ODDS  O_ODDS  \
# 13        469  ...            0       12       14     0.0     0.0
# 35        422  ...            0        9        7     0.0     0.0
# 71        654  ...            0       10       10     0.0     0.0
#
#     UO_STANDARD  HOME_SCORE  AWAY_SCORE  MCH_SCORE  GAME_RESULT
# ...

# %%
a = unov.groupby(['Home']).rolling(window = 3).mean().reset_index(drop=False, inplace=False)
a
# Out:
# C:\Users\NTX550\AppData\Local\Temp\ipykernel_9672\3473147069.py:1: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Away', 'Date'], dtype='object')
#   a = unov.groupby(['Home']).rolling(window = 3).mean().reset_index(drop=False, inplace=False)
#                          Home  level_1  H_Possession  A_Possession  \
# 0                     Arsenal        2           NaN           NaN
# 1                     Arsenal       27           NaN           NaN
# 2                     Arsenal       34     55.400000     44.600000
# 3                     Arsenal       67     56.233333     43.766667
# 4                     Arsenal       74     65.933333     34.066667
# ...                       ...      ...           ...           ...
# 1624  Wolverhampton Wanderers     1546     60.333333     39.666667
# ...

# %%
# home 기준 롤링
a = unov.groupby(['Home']).rolling(window = 3).mean().shift(1).reset_index(drop=False, inplace=False)
a
# Out:
# C:\Users\NTX550\AppData\Local\Temp\ipykernel_3168\3920876077.py:1: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Away', 'Date'], dtype='object')
#   c = unov.groupby(['Home']).rolling(window = 3).mean().shift(1).reset_index(drop=False, inplace=False)
#                          Home  level_1  H_Possession  A_Possession  \
# 0                     Arsenal        2           NaN           NaN
# 1                     Arsenal       27           NaN           NaN
# 2                     Arsenal       34           NaN           NaN
# 3                     Arsenal       67     55.400000     44.600000
# 4                     Arsenal       74     56.233333     43.766667
# ...                       ...      ...           ...           ...
# 1624  Wolverhampton Wanderers     1546     52.300000     47.700000
# ...

# %%
# away 기준 롤링
b = unov.groupby(['Away']).rolling(window = 3).mean().shift(1).reset_index(drop=False, inplace=False)
b
# Out:
# C:\Users\NTX550\AppData\Local\Temp\ipykernel_3168\1315405634.py:1: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Date', 'Home'], dtype='object')
#   b = unov.groupby(['Away']).rolling(window = 3).mean().shift(1).reset_index(drop=False, inplace=False)
#                          Away  level_1  H_Possession  A_Possession  \
# 0                     Arsenal       10           NaN           NaN
# 1                     Arsenal       48           NaN           NaN
# 2                     Arsenal       54           NaN           NaN
# 3                     Arsenal       79     51.600000     48.400000
# 4                     Arsenal      123     57.866667     42.133333
# ...                       ...      ...           ...           ...
# 1624  Wolverhampton Wanderers     1521     48.900000     51.100000
# ...
